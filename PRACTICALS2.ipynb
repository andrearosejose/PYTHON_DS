# %%
import matplotlib.pyplot as plt
from scipy.stats import binom
import pandas as pd
import numpy as np
import seaborn as sns

# %%
n=1000
p=0.05
x = np.arange(0, 101)
y= binom.pmf(x, n, p)

plt.figure(figsize=(10,5))
plt.bar(x, y, color='green')
plt.title('Binomial Distribution ')
plt.xlabel('Number of Successes')   
plt.ylabel('Probability')


probalitity_exactly_50 = binom.pmf(50, n, p)
probalitity_fewer_than_30 = binom.cdf(30, n, p)
probalitity_greater_than_30 = 1-binom.cdf(30, n, p)
print(f"Probability of exactly 50 clicks: {probalitity_exactly_50:.4f}")
print(f"Probability of fewer than 30 clicks: {probalitity_fewer_than_30:.4f}")
print(f"Probability of greater than 30 clicks: {probalitity_greater_than_30:.4f}")
# Out:
# Probability of exactly 50 clicks: 0.0578
# Probability of fewer than 30 clicks: 0.0013
# Probability of greater than 30 clicks: 0.9987
